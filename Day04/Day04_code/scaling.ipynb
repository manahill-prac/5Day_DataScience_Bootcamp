# %%
#dataset for scaling
import pandas as pd

df = pd.DataFrame({
    'Name':   ['Ali', 'Sara', 'Ahmed', 'Zara', 'Bilal', 'Hina'],
    'Age': [18, 20, 22, 19,26,18],
    'Education': ['Matric', 'Bachelors', 'Masters', 'Bachelors', 'PhD', 'Matric'],
    'City':   ['Karachi', 'Lahore', 'Islamabad', 'Karachi', 'Lahore', 'Islamabad'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Salary': [30000, 55000, 75000, 50000, 95000, 28000]
})

print("Before Encoding:")
print(df)
# Out:
# Before Encoding:
#     Name  Age  Education       City  Gender  Salary
# 0    Ali   18     Matric    Karachi    Male   30000
# 1   Sara   20  Bachelors     Lahore  Female   55000
# 2  Ahmed   22    Masters  Islamabad    Male   75000
# 3   Zara   19  Bachelors    Karachi  Female   50000
# 4  Bilal   26        PhD     Lahore    Male   95000
# 5   Hina   18     Matric  Islamabad  Female   28000

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Age', 'Salary']] = scaler.fit_transform(
    df[['Age', 'Salary']]
)

print("\nAfter StandardScaler:")
print(df[['Age', 'Salary']].round(2))
# Out:
# After StandardScaler:
#     Age  Salary
# 0 -0.89   -1.07
# 1 -0.18   -0.02
# 2  0.53    0.82
# 3 -0.53   -0.23
# 4  1.95    1.66
# 5 -0.89   -1.16

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler = MinMaxScaler()
df[['Age', 'Salary']] = mm_scaler.fit_transform(
    df[['Age', 'Salary']]
)

print("\nAfter MinMaxScaler:")
print(df[['Age', 'Salary']].round(2))
# Out:
# After MinMaxScaler:
#     Age  Salary
# 0  0.00    0.03
# 1  0.25    0.40
# 2  0.50    0.70
# 3  0.12    0.33
# 4  1.00    1.00
# 5  0.00    0.00
